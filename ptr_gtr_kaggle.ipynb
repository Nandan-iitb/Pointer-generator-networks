# %%
#Import utils and libraries
import pandas as pd
import numpy as np
import os
import pickle
from collections import Counter

from typing import Callable, Optional
from copy import deepcopy
import math
# Import pytoch libraries and modules 
import torch
import torch.nn as nn
from torch.nn import functional as F
from torch import optim
from torch.nn.utils import clip_grad_norm_
from torch.utils.data import Dataset, DataLoader
from torch.nn.utils.rnn import pack_padded_sequence, pad_packed_sequence
import pkbar
from rouge import Rouge
#Import libraries for text procesing
import nltk
from nltk.tokenize import word_tokenize
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
class Parameters:
  # Model Parameters
  hidden_size: int = 150  # of the encoder; default decoder size is doubled if encoder is bidi
  dec_hidden_size = 200  # if set, a matrix will transform enc state into dec state
  embed_size: int = 128 # Size of the embedding vectors
  eps=1e-31
  batch_size=16 
  enc_bidi = True #Set the encoder as bidirectional
  enc_rnn_dropout = 0.1 # Set the dropout parameter in the encoder
  enc_attn = True #Activate the encoder attention
  dec_attn = True #Activate the decoder attention
  pointer = True #Activate the pointer generator mechanism
  # Set different dropout probabilities in the decoder
  dec_in_dropout=0.1
  dec_rnn_dropout=0.1
  dec_out_dropout=0.1
  # Vocabulary and data parameters
  max_src_len: int = 65  # exclusive of special tokens such as EOS
  max_tgt_len: int = 15  # exclusive of special tokens such as EOS
  vocab_min_frequency: int = 3
  # Data paths
  embed_file = r"/workspace/myproject/Kaggle_ptr_gtr/devanagari_full_one_hot_encoding.txt"#"C:\Users\ajayp\OneDrive\Desktop\IITB Files\Bharat-GPT\New folder\glove_6B_100d\glove.6B.100d.txt" # use pre-trained embeddings
  data_path = r"/workspace/myproject/train_w_splits - train_w_splits.csv"#"C:\Users\ajayp\OneDrive\Desktop\IITB Files\Bharat-GPT\New folder\vnn_csvs\cl_train_news_summary_more.csv"
  val_data_path = r"/workspace/myproject/val_w_splits - val_w_splits.csv"#"C:\Users\ajayp\OneDrive\Desktop\IITB Files\Bharat-GPT\New folder\vnn_csvs\cl_train_news_summary_more.csv"
  test_data_path = r"/workspace/myproject/test_w_splits - test_w_splits(1).csv"#"C:\Users\ajayp\OneDrive\Desktop\IITB Files\Bharat-GPT\New folder\vnn_csvs\cl_valid_news_summary_more.csv"
  # Parameters to save the model
  resume_train = False
  encoder_weights_path='encoder_sum.pt'
  decoder_weights_path='decoder_sum.pt'
  encoder_decoder_adapter_weights_path='adapter_sum.pt'
  losses_path='val_losses.pkl'
  print_every = 100

# %%
# def simple_tokenizer(text, lower=False, newline=None):
#   if lower:
#     text = text.lower()
#   if newline is not None:  # replace newline by a token
#     text = text.replace('\n', ' ' + newline + ' ')
#   return text.split()
def simple_tokenizer(text, lower=False, newline=None):
    if lower:
        text = text.lower()
    if newline is not None:  # replace newline by a token
        text = text.replace('\n', newline)
    return list(text)

# %%
class Vocab(object):
  PAD = 0
  SOS = 1
  EOS = 2
  UNK = 3

  def __init__(self):
    ''' Initialize the structuresto store the information about the vocabulary'''
    self.word2index = {}
    self.word2count = Counter()
    self.reserved = ['<PAD>', '<SOS>', '<EOS>', '<UNK>']
    self.index2word = self.reserved[:]
    self.embeddings = None

  def add_words(self, words):
    ''' Add words to the vocabulary'''
    for word in words:
      #if it is an unseen word  
      if word not in self.word2index:
        #Include the word in the mapping from word to index
        self.word2index[word] = len(self.index2word)
        # Include the word in the indexes
        self.index2word.append(word)
    # Increment the count of ocurrencies of the word to 1
    self.word2count.update(words)
  
  def load_embeddings(self, file_path: str, dtype=np.float32):
    ''' Load the embedding vectors from a file into the vocabulary'''
    num_embeddings = 0
    vocab_size = len(self)
    print(vocab_size)
    with open(file_path, 'r', encoding = 'utf-8') as f:
      # For every word in the embedding vectors
      for line in f:
        line = line.split()
        word = line[0]
        # self.add_words([word])
        # Get the index of the embedded word
        idx = self.word2index.get(word)
        if idx is not None:
          # Extract the embedding vector of the word
          vec = np.array(line[1:], dtype=dtype)
          #If the embedding vector is not initialized
          if self.embeddings is None:
            # Set the embeddings dimension, initialize the embedding vector to zeros
            n_dims = len(vec)
            self.embeddings = np.random.normal(np.zeros((vocab_size, n_dims))).astype(dtype)
            self.embeddings[self.PAD] = np.zeros(n_dims)
          # Store the embedding in the array of embeddings 
          self.embeddings[idx] = vec          
          num_embeddings += 1
      print(num_embeddings)
    return num_embeddings

  def save_to_file(self, filename):
    ''' Save the Vocab object to a file'''
    with open(filename,'wb') as f:
        pickle.dump(self,f) 

  def __getitem__(self, item):
    ''' Get the next item when iterating over the instance'''
    if type(item) is int:
      return self.index2word[item]
    return self.word2index.get(item, self.UNK)

  def __len__(self):
    ''' Return the length of the instance or vocabulary'''
    return len(self.index2word)


def load_vocab(filename):
    ''' Load a Vocab instance from a file'''
    with open(filename,'rb') as f:
        v = pickle.load(f)
    return v

# %%
class Dataset(object):
  ''' Create a Class to store the data input and its features'''
  def __init__(self, filename: str, tokenize: Callable=simple_tokenizer, max_src_len: int=None,
               max_tgt_len: int=None, max_rows: int=None, truncate_src: bool=False, truncate_tgt: bool=False):
    print("Reading dataset %s..." % filename, end=' ', flush=True)
    # Save the filename and initialize the variables
    self.filename = filename
    self.pairs = []
    self.src_len = 0
    self.tgt_len = 0
    self.max_rows = max_rows

    #Read the csv file, using max rows if it is defined
    if max_rows is None:
        df = pd.read_csv(filename, encoding='utf-8')
    else:
        df = pd.read_csv(filename, encoding='utf-8', nrows=max_rows)
    # Tokenize the source texts
    sources = df['Word'].apply(lambda x : tokenize(x))
    # Truncate the sources texts
    if truncate_src:
        sources = [src[:max_src_len] if len(src)>max_src_len else src for src in sources]
    # Tokenize the targets
    targets = df['Splits'].apply(lambda x : tokenize(x))
    # Trucate the targets
    if truncate_tgt:
        targets = [tgt[:max_tgt_len] if len(tgt)>max_tgt_len else tgt for tgt in targets]
        
    # Calculate the length of every source and targets        
    src_length = [len(src)+1 for src in sources]
    tgt_length = [len(tgt)+1 for tgt in targets]
    #Calculate the max length of the sources and the targets
    max_src = max(src_length)
    max_tgt = max(tgt_length)
    #Create a tuple contaiing source,target,source length, target length
    self.src_len = max_src
    self.tgt_len = max_tgt
    # Insert the source text and target in the pairs class atribute
    self.pairs.append([(src, tgt, src_len, tgt_len) for src,tgt,src_len,tgt_len in zip(sources,targets,src_length,tgt_length)])
    self.pairs = self.pairs[0]
    print("%d pairs." % len(self.pairs))

  def build_vocab(self, min_freq, embed_file: str=None) -> Vocab:
    ''' Build the vocabulary extracted from the texts in the object class
        Input:
        - min_freq: integer, minimum ocurrencies needed to include the word in the vocab
        - embed_file: string, path + filename of the embeddings file
    '''
    # Extract the words in the whole corpus
    total_words=[src+tgr for src,tgr,len_src,len_tgr in self.pairs]
    total_words = [item for sublist in total_words for item in sublist]
    # Create a counter to count the ocurrencies of every word in the corpus
    word_counts = Counter(total_words)
    # Create a vocabulary object
    vocab=Vocab()
    for word,count in word_counts.items():
        # If occurencies of the word are bigger then min_freq
        if(count>0):#min_freq:
            # Include the cord in the vocabulary
            vocab.add_words([word])  
    # Load the embeddings in the vocab object
    count = vocab.load_embeddings(embed_file)
    print("%d pre-trained embeddings loaded." % count)

    return vocab

# %%
class MyDataset(nn.Module):
    ''' A Dataset Class where we store all the data needed during the training phase'''
    
    def __init__(self, src_sents, trg_sents, vocab):
      '''Initialize the instance and store the source texts, targets or summaries '''
      self.src_sents = src_sents
      self.trg_sents = trg_sents
      self.vocab=vocab
      # Keep track of how many data points.
      self._len = len(src_sents)

    def __getitem__(self, index):
        ''' Return the ith items from the object
            Input:
            - Index: integer, index of the items to return
            Output:
            - a dictionary with keys x the source texts, y the targets, 
              x_len length of source texts, y_len the length of targets
        '''
        return {'x':self.src_sents[index], 
                'y':self.trg_sents[index], 
                'x_len':len(self.src_sents[index]), 
                'y_len':len(self.trg_sents[index])}
    
    def __len__(self):
        ''' Return the length of the object'''
        return self._len

# %%
def tensorize(vocab, tokens):
    ''' Convert the tokens received to a tensor '''
    return torch.tensor([vocab[token] for token in tokens])

def pad_sequence(vectorized_sent, max_len):
    ''' Padding the sentence (tensor) to max_len '''
    pad_dim = (0, max_len - len(vectorized_sent))
    return F.pad(vectorized_sent, pad_dim, 'constant').tolist()

def preprocess(x,y,p,vocab):
    ''' Prepare a source text x and a target summary y: convert them to tensors,
        pads the sentences to its max length.
    '''
    # Convert x and y to tensors using the vocabulary
    tensors_src = tensorize(vocab, x)
    tensors_trg = tensorize(vocab, y) 
    # Return the padded sequence of x and y and its length
    return {'x':pad_sequence(tensors_src, p.max_src_len), #¿max_source_len?
          'y':pad_sequence(tensors_trg, p.max_tgt_len), #¿,ax_target_len?
          'x_len':len(tensors_src), 
          'y_len':len(tensors_trg)}

def sort_batch_by_len(data_dict,p,vocab):
    ''' Return a batch of sentences processed and ordered by its length
    '''
    data=[]
    res={'x':[],'y':[],'x_len':[],'y_len':[]}
    # For every x and y in the data input
    for i in range(data_dict['x_len']):
        # Preprocess and tokenize the x and y
        data.append(preprocess(data_dict['x'][i],data_dict['y'][i],p,vocab))
    # For every preprocessed text, recreate the x and y lists
    for i in range(len(data)):
        res['x'].append(data[i]['x'])
        res['y'].append(data[i]['y'])
        res['x_len'].append(len(data[i]['x']))
        res['y_len'].append(len(data[i]['y']))  
    
    # Sort indices of data in batch by lengths.
    sorted_indices = np.array(res['x_len']).argsort()[::-1].tolist()
    # Create a batch of data ordered by its length
    data_batch = {name:[_tensor[i] for i in sorted_indices]
                  for name, _tensor in res.items()}
    return data_batch

# %%
class EncoderRNN(nn.Module):
  ''' Define an encoder in a seq2seq architecture'''
  def __init__(self, embed_size, hidden_size, bidi=True, rnn_drop: float=0):
    super(EncoderRNN, self).__init__()
    # Set the hidden size
    self.hidden_size = hidden_size
    # Activate bidirectional mode
    self.num_directions = 2 if bidi else 1
    # Define the GRU layer of the encoder
    self.gru = nn.GRU(embed_size, hidden_size, bidirectional=bidi, dropout=rnn_drop)

  def forward(self, embedded,hidden,input_lengths=None):
    ''' Run a Forward pass of the encoder to return outputs
        Input:
        - embedded: tensor, the embedding of the input data (word of the soure text)
        - hidden: a tensor, the previous hidden state of the encoder
        - input:lengths: a list of integers, length of the inputs 
    '''
    # Pack the padded sequence of the embedded input
    if input_lengths is not None:
      input_lengths = input_lengths.cpu()
      embedded = pack_padded_sequence(embedded, input_lengths,batch_first=True)
    
    # Apply the GRU layer of the encoder
    output, hidden = self.gru(embedded,hidden)
    
    # Pad the sequence output
    if input_lengths is not None:
      output, _ = pad_packed_sequence(output)
    # If bidirectional
    if self.num_directions > 1:
      # Transform the hidden state tensor  
      # hidden: (num directions, batch, hidden) => (1, batch, hidden * 2)
      batch_size = hidden.size(1)
      hidden = hidden.transpose(0, 1).contiguous().view(1, batch_size,
                                                        self.hidden_size * self.num_directions)
    return output, hidden

  def init_hidden(self, batch_size, device):
    ''' Initialize the hidden state of the encoder to zeros: num_directions, batch size, hidden size '''
    return torch.zeros(self.num_directions, batch_size, self.hidden_size, device=device)

# %%
class DecoderRNN(nn.Module):
  ''' Define a decoder with atention in a seq2seq architecture'''
  def __init__(self, vocab_size, embed_size, hidden_size, enc_attn=True, dec_attn=True,
               enc_attn_cover=True, pointer=True,
               in_drop: float=0, rnn_drop: float=0, out_drop: float=0, enc_hidden_size=None,
               epsilon: float=0.0, device: str="cpu"):
    ''' Initialize the decoder instance defining its parameters:
            Input:
                - vocab_size: integer, number of words in the vocabulary 
                - embed_size: integer, size of the embedding layer
                - hidden_size: integer, size of the hidden layer (Hyperparameter)
                - enc_attn: activate the attention in the encoder
                - dec_attn: activate the attention in the decoder
                - enc_attn_cover: activate the coverage mechanism in the attention
                - pointer: activate the pointer generation
                - in_drop: dropout probability to apply to the input of the decoder
                - rnn_drop: dropout probability to apply to the GRU layer of the decoder
                - out_drop: dropout probability to apply to the output of the decoder
                - enc_hidden_size: dimension if the hidden state of the encoder
                - epsilon: float
                - device: cpu or gpu, device to store the tensors
    '''

    super(DecoderRNN, self).__init__()
    # Set the attibutes
    self.vocab_size = vocab_size
    self.hidden_size = hidden_size
    self.combined_size = hidden_size
    self.device = device
    self.eps = epsilon
    # Define the input dropout layer 
    self.in_drop = nn.Dropout(in_drop) if in_drop > 0 else None
    # Define the GRU layer
    self.gru = nn.GRU(embed_size, hidden_size, dropout=rnn_drop)
    
    # Set the hidden size of the encoder to the hidden size of the decoder if it is not defined
    if not enc_hidden_size: enc_hidden_size = self.hidden_size
    # Bilinear layer of the encoder
    self.enc_bilinear = nn.Bilinear(hidden_size, enc_hidden_size, 1)
    
    self.combined_size += enc_hidden_size
    if enc_attn_cover:
      # Initialize the weights of the coverage mechanism
      self.cover_weight = nn.Parameter(torch.rand(1))

    # Bilinear layer of the encoder
    self.dec_bilinear = nn.Bilinear(self.hidden_size, self.hidden_size, 1)
    self.combined_size += self.hidden_size
    
    # Define the output dropout layer
    self.out_drop = nn.Dropout(out_drop) if out_drop > 0 else None
    # Define the pointer generator layer
    self.ptr = nn.Linear(self.combined_size, 1)

    # Define the linear layer at the output
    self.out = nn.Linear(self.combined_size, vocab_size)

  def forward(self, embedded, hidden, encoder_hidden=None, decoder_states=None, coverage_vector=None, *,
              encoder_word_idx=None, ext_vocab_size: int=None, log_prob: bool=True):
    ''' Run a Forward pass of the decoder to return outputs
        Input:
        - embedded: tensor, the embedding of the input data (decoder output in the last step
        - hidden: a tensor, the previous hidden state of the decoder
        - decoder_states: tensor, hidden state of the decoder in the last step
        - coverage_vector: tensor, coverage vector at this step
        - encoder_word_idx: tensor, indexes of the words in the source text
        - ext_vocab_size: integer, vocabulary size of the extended vocabulary
        - log_prob: bool, use of Log Softmax or Softmax in the output
    '''
    #print('Self Dev:',self.device)
    # Set the batch sze and initialize the combined context vectors
    batch_size = embedded.size(0)
    combined = torch.zeros(batch_size, self.combined_size, device=self.device)
    # Apply the dropout layer to the input data
    if self.in_drop: embedded = self.in_drop(embedded)
    # Apply the GRU layer
    output, hidden = self.gru(embedded.unsqueeze(0), hidden)  # unsqueeze and squeeze are necessary
    combined[:, :self.hidden_size] = output.squeeze(0)        # as RNN expects a 3D tensor (step=1)
    offset = self.hidden_size
    enc_attn, prob_ptr = None, None  # for visualization

    # Set the encoder steps and total size
    num_enc_steps = encoder_hidden.size(0)
    enc_total_size = encoder_hidden.size(2)
    #print('Encoder hidden: ', encoder_hidden.shape,' Hidden: ', hidden.shape)
    # Apply the Bilinear layer
    enc_attn = self.enc_bilinear(hidden.expand(num_enc_steps, batch_size, -1).contiguous(),encoder_hidden)
    # print(hidden.shape,hidden.expand(num_enc_steps, batch_size, -1).shape,encoder_hidden.shape,enc_attn.shape)
    
    # Update the attention weigths
    if coverage_vector is not None:
        enc_attn += self.cover_weight * torch.log(coverage_vector.transpose(0, 1).unsqueeze(2) + self.eps)
    # Transpose the attention vectors
    # transpose => (batch size, num encoder states, 1)
    enc_attn = F.softmax(enc_attn, dim=0).transpose(0, 1)
    
    # Calculate the context vectors 
    enc_context = torch.bmm(encoder_hidden.permute(1, 2, 0), enc_attn)
    # print(enc_context.shape,enc_context.squeeze(2).shape)
    
    # Update the combined vector with the context vectors 
    combined[:, offset:offset+enc_total_size] = enc_context.squeeze(2)
    offset += enc_total_size
    enc_attn = enc_attn.squeeze(2)
    
    # Set the decoder attention vectors
    if decoder_states is not None and len(decoder_states) > 0:
      dec_attn = self.dec_bilinear(hidden.expand_as(decoder_states).contiguous(),
                                      decoder_states)
      dec_attn = F.softmax(dec_attn, dim=0).transpose(0, 1)
      dec_context = torch.bmm(decoder_states.permute(1, 2, 0), dec_attn)
      combined[:, offset:offset + self.hidden_size] = dec_context.squeeze(2)
      offset += self.hidden_size
    
    # Prepare the data to apply the pointer generator
    out_embed = combined
    logits = self.out(out_embed)  # (batch size, vocab size)

    # Distribute probabilities between generator and pointer
    prob_ptr = torch.sigmoid(self.ptr(combined))  # (batch size, 1)
    prob_gen = 1 - prob_ptr
    # add generator probabilities to output
    gen_output = F.softmax(logits, dim=1)  # can't use log_softmax due to adding probabilities
    output = prob_gen * gen_output
    # Dfine the padding dimension
    pad_dim = (0, ext_vocab_size - output.size(1))
    # Pad the output tensir
    output=F.pad(output, pad_dim, 'constant')

    # add pointer probabilities to output
    ptr_output = enc_attn
    encoder_word_idx_l = encoder_word_idx.long()
    # Calculate the output tensor    
    try:
        output.scatter_add_(1, encoder_word_idx_l, prob_ptr * ptr_output)
    except:
        prob_po = prob_ptr * ptr_output 
        print(output.shape,encoder_word_idx_l.shape,prob_ptr.shape, ptr_output.shape, prob_po.shape)
        print(output)
        print(encoder_word_idx_l)
        print(prob_po)
        output.scatter_add_(1, encoder_word_idx_l, prob_po)
        
    # Apply the log in the output
    output = torch.log(output + self.eps)

    return output, hidden, enc_attn, prob_ptr

# %%
def get_coverage_vector(enc_attn_weights):
    """Combine the past attention weights into one vector"""
    coverage_vector = torch.sum(torch.cat(enc_attn_weights), dim=0)
    
    return coverage_vector

# %%
def get_next_batch(data, p, vocab, i, batch_size, device):
    ''' Generate and return the next batch of the data during training
        Input:
        - data: list, input data to the model
        - p: a class Parameters object, model and training parameters
        - vocab: a class Vocab object, vocabulary of the data
        - i: integer, index or iterator
        - batch_size: integer, batch size
        - device: string, where to train the model, cpu or gpu 
    '''
    #Create a copy of the vocabulary
    vocab_ext=deepcopy(vocab)

    #Get the next batch
    try:
        data_dict=data[i:i+batch_size]
    except:
        data_dict=data[i:len(data)]
    # Create a batch from an extended cocabulary
    data_batch = sort_batch_by_len(data_dict,p,vocab_ext)
    # Create an extended cocabulary
    for word in data_dict['x']:
        vocab_ext.add_words(word)
            
    # Create a batch from an extended cocabulary
    data_batch_extra=sort_batch_by_len(data_dict,p,vocab_ext)
    #Create tha inputs in the extended version        
    x_extra=torch.tensor(data_batch_extra['x']).to(device)
    
    # Transform the batch to tensors
    x, x_len = torch.tensor(data_batch['x']).to(device), torch.tensor(data_batch['x_len']).to(device)
    y, y_len = torch.tensor(data_batch['y']).to(device), torch.tensor(data_batch['y_len']).to(device)

    return x, x_len, y, y_len, x_extra, vocab_ext

# %%
def train(dataset,val_dataset,vocab,p,embedding_weights, learning_rate, num_epochs):
    ''' Run all the steps in the training phase
        Input:
        - dataset: Dataset object, training data
        - val_dataset: Dataset object, validation data
        - vocab: a class Vocab object, the vocabulary of the datasets
        - p: a class Parameters object, model and training parameters
        - embedding_weigths: tensor, the embedding vectors
        - learning_rate: float, learning rate parameter
        - num_epochs: integer, number of epochs of the training
    '''
    # Set some variables like eps, batch size and device
    eps = p.eps
    batch_size =p.batch_size
    DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    
    #Create an adapter between encoder hidden state to decoder hidden size 
    enc_dec_adapter = nn.Linear(p.hidden_size * 2, p.dec_hidden_size).to(DEVICE)
    #Create an embedding layer with pretrained weigths
    embedding = nn.Embedding(len(vocab), p.embed_size, padding_idx=vocab.PAD,
                             _weight=embedding_weights).to(DEVICE)
    
    # Do not train the embeddings
    embedding.weight.requires_grad=False
    #Create the encoder
    encoder = EncoderRNN(p.embed_size, p.hidden_size, p.enc_bidi,rnn_drop=p.enc_rnn_dropout).to(DEVICE)
    #Create the decoder
    decoder = DecoderRNN(len(vocab), p.embed_size, p.dec_hidden_size,
                                  enc_attn=p.enc_attn, dec_attn=p.dec_attn,
                                  pointer=p.pointer,
                                  in_drop=p.dec_in_dropout, rnn_drop=p.dec_rnn_dropout,
                                  out_drop=p.dec_out_dropout, enc_hidden_size=p.hidden_size * 2,
                                  device=DEVICE, epsilon=p.eps).to(DEVICE)
    
    # If the model components have been training, we restore them from a previous save
    if(os.path.exists(p.encoder_weights_path) and p.resume_train):
        encoder.load_state_dict(torch.load(p.encoder_weights_path,map_location=torch.device(DEVICE)))
    if(os.path.exists(p.decoder_weights_path) and p.resume_train):
        decoder.load_state_dict(torch.load(p.decoder_weights_path,map_location=torch.device(DEVICE)))
    if(os.path.exists(p.encoder_decoder_adapter_weights_path) and p.resume_train):   
        enc_dec_adapter.load_state_dict(torch.load(p.encoder_decoder_adapter_weights_path,map_location=torch.device(DEVICE)))
    
    # Create a Dataset class containing the training data
    cnn_data=MyDataset([pair[0] for pair in dataset.pairs],[pair[1] for pair in dataset.pairs],vocab)
    
    # Create a Dataset class containing the validation data
    #CHECK IF CREATING A VOCAB FOR VALIDATION IS RIGHT
    val_data=MyDataset([pair[0] for pair in val_dataset.pairs],[pair[1] for pair in val_dataset.pairs],vocab)
    # print(cnn_data[:3]['x_len'])
    
    # DEfine the loss function
    criterion = nn.NLLLoss(ignore_index=vocab.PAD)
    # Define the optimizers for the encoder, decoder and the adapter
    encoder_optimizer = optim.Adam(encoder.parameters(), lr=learning_rate)
    decoder_optimizer = optim.Adam(decoder.parameters(), lr=learning_rate)
    adapter_optimizer=optim.Adam([{'params':enc_dec_adapter.parameters()}], lr=learning_rate)
    # Record the losses
    losses=[]
    val_losses=[]
    #Load the losses from previous trainings
    if(os.path.exists(p.losses_path) and p.resume_train):
      with open(p.losses_path,'rb') as f:
        val_losses=pickle.load(f)
        
    #Run training for num_epochs
    for _e in range(num_epochs):
        i=0
        #Create a progress bar 
        print('\nEpoch: %d/%d' % (_e + 1, num_epochs))
        kbar = pkbar.Kbar(target=len(cnn_data), width=8)
        #for every batch in the training data 
        while i<len(cnn_data):
            
            # Reset the gradients for the forward phase
            encoder_optimizer.zero_grad()
            decoder_optimizer.zero_grad()
            adapter_optimizer.zero_grad()

            # Extract the data for the next batch
            x, x_len, y, y_len, x_extra, vocab_ext = get_next_batch(cnn_data, p, vocab, i, batch_size, device=DEVICE)
    
            # Apply the embedding layer in the encoder
            encoder_embedded = embedding(x)
            # Create the init hidden state of the encoder
            encoder_hidden=encoder.init_hidden(x.size(0), DEVICE)
            # Forward pass in the encoder
            encoder_outputs, encoder_hidden =encoder(encoder_embedded,encoder_hidden,x_len)
            #Create the init input to the encoder
            decoder_input = torch.tensor([vocab.SOS] * x.size(0), device=DEVICE)
            # Adapt the encoder hidden to the encoder hidden size
            decoder_hidden = enc_dec_adapter(encoder_hidden)
            
            decoder_states = []
            enc_attn_weights = []
            loss=0
            # For every token in the target
            for di in range(y.size(1)):
                #Apply the embedding layer to the decoder input
                decoder_embedded = embedding(decoder_input)
                # If activation of encoder attention is on 
                if enc_attn_weights:
                    coverage_vector = get_coverage_vector(enc_attn_weights)
                else:
                    coverage_vector = None
                    
                #Forward pass to the decoder
                decoder_output, decoder_hidden, dec_enc_attn, dec_prob_ptr = decoder(decoder_embedded, decoder_hidden, encoder_outputs,
                            torch.cat(decoder_states) if decoder_states else None, coverage_vector,
                            encoder_word_idx=x_extra,log_prob=True,ext_vocab_size=len(vocab_ext))  
                #Move the tensors to the device
                decoder_output.to(DEVICE)
                decoder_hidden.to(DEVICE)
                dec_enc_attn.to(DEVICE)
                dec_prob_ptr.to(DEVICE)
                
                #Save the decoder hidden state
                decoder_states.append(decoder_hidden)
                #Calculate the probability distribution of the decoder outputs
                prob_distribution = torch.exp(decoder_output)# if log_prob else decoder_output
                #Get the largest element 
                _, top_idx = decoder_output.data.topk(1)
                # Set the current target word to our goal
                gold_standard = y[:,di]
                # Apply the loss function
                nll_loss= criterion(decoder_output, gold_standard)  
                if not math.isnan(nll_loss):  
                    loss+=nll_loss
                
                #Set the decoder input to the target word or token 
                decoder_input = y[:,di]
                #Calculate the coverage loss
                if (coverage_vector is not None and criterion): 
                    coverage_loss = torch.sum(torch.min(coverage_vector, dec_enc_attn)) / batch_size #* cover_loss            
                    loss+=coverage_loss
                    
                #Store the attention weights
                enc_attn_weights.append(dec_enc_attn.unsqueeze(0)) 
                
            #Apply the backward to get the loss
            loss.backward()
            # Clipping the weights in the encoder, decoder and the adapter
            clip_grad_norm_(encoder.parameters(), 1)
            clip_grad_norm_(decoder.parameters(), 1)
            clip_grad_norm_(enc_dec_adapter.parameters(), 1)
            # Update the parameters
            encoder_optimizer.step()
            decoder_optimizer.step()
            adapter_optimizer.step() 
            #Print the progress bar
            if i%(p.print_every*batch_size)==0:
                kbar.update(i, values=[("loss", loss.data.item())])
            # Get the next batch
            i+=batch_size
            
        # Calculate the final loss on the training    
        loss=loss.data.item()/x.size(0)
        print(x.size())
        
        kbar.add(1, values=[("loss", loss)])
        
        #Repeat the process on the validation dataset
        kbar2 = pkbar.Kbar(target=len(val_data), width=8)
        
        # calculating validation loss
        val_loss=0
        i=0
        while(i<len(val_data)):
            # Reset the gradients for the forward phase
            encoder_optimizer.zero_grad()
            decoder_optimizer.zero_grad()
            adapter_optimizer.zero_grad()
            # Get the next batch of the validation data
            x, x_len, y, y_len, x_extra, vocab_ext = get_next_batch(val_data, p, vocab, i, batch_size, device=DEVICE)
            # Forward pass of the encoder
            encoder_embedded = embedding(x)
            encoder_hidden=encoder.init_hidden(x.size(0), device=DEVICE)
            encoder_outputs, encoder_hidden =encoder(encoder_embedded,encoder_hidden,x_len)
            decoder_input = torch.tensor([vocab.SOS] * x.size(0), device=DEVICE)
            decoder_hidden = enc_dec_adapter(encoder_hidden)
            
            decoder_states = []
            enc_attn_weights = []
            # For every word in the output
            for di in range(y.size(1)):
                try:
                    #Get the embedding vector of the input to the decoder
                    decoder_embedded = embedding(decoder_input)
                except:
                    print('Dec input: ',decoder_input.shape,' x:', x.shape,' x_len:',x_len.shape, ' Vocab:', 
                          vocab.embeddings.shape,' Vocab Ext:', vocab_ext.embeddings.shape)
                    decoder_embedded = embedding(decoder_input)
                # Generate the coverage vectors if neccessary
                if enc_attn_weights:
                    coverage_vector = get_coverage_vector(enc_attn_weights)
                else:
                    coverage_vector = None
                # Fordward pass ti the decoder
                decoder_output, decoder_hidden, dec_enc_attn, dec_prob_ptr = decoder(decoder_embedded, decoder_hidden, encoder_outputs,
                            torch.cat(decoder_states) if decoder_states else None, coverage_vector,
                            encoder_word_idx=x_extra,log_prob=True,ext_vocab_size=len(vocab_ext))  
                # Move the tensors to the device, gou or cpu
                decoder_output.to(DEVICE)
                decoder_hidden.to(DEVICE)
                dec_enc_attn.to(DEVICE)
                dec_prob_ptr.to(DEVICE)
                # Stores the hidden states of the decoder
                decoder_states.append(decoder_hidden)      
                prob_distribution = torch.exp(decoder_output)# if log_prob else decoder_output
                # Get the output token with the highest probability
                _, top_idx = decoder_output.data.topk(1)
                gold_standard = y[:,di]
                # Apply the loss function
                nll_loss= criterion(decoder_output, gold_standard)   
                print(nll_loss)
                if not math.isnan(nll_loss): 
                    val_loss+=nll_loss.data.item()
                
                # Set the decoder input to the last output from the decoder
                decoder_input = top_idx.view(-1) #y[:,di]
                # update the coverage vector
                if (coverage_vector is not None and criterion): #and cover_loss > 0:
                    coverage_loss = torch.sum(torch.min(coverage_vector, dec_enc_attn)) / batch_size #* cover_loss            
                    val_loss+=coverage_loss.data.item()
                # Collect the attention weights in the step    
                enc_attn_weights.append(dec_enc_attn.unsqueeze(0))  
            # Print the progress
            if i%(p.print_every*batch_size)==0:
                kbar2.update(i, values=[("Val loss", val_loss)])

            i+=batch_size
            
        #Calculate the validation loss
        avg_val_loss=val_loss/len(val_data)        
        #print('training loss:{}'.format(loss),'validation loss:{}'.format(avg_val_loss))
        kbar2.add(1, values=[("Train loss", loss), ("Val loss", val_loss), ("Avg Val loss", avg_val_loss)])
        
        # Save the mnodel and results to disk
        if(len(val_losses)>0 and avg_val_loss<min(val_losses)):
            torch.save(encoder.state_dict(), p.encoder_weights_path)
            torch.save(decoder.state_dict(), p.decoder_weights_path)
            torch.save(enc_dec_adapter.state_dict(), p.encoder_decoder_adapter_weights_path)
            # torch.save(embedding.state_dict(), '/home/svu/e0401988/NLP/summarization/embedding_sum.pt')
        val_losses.append(avg_val_loss) 
    
    with open(p.losses_path,'wb') as f:
        pickle.dump(val_losses,f)

# %%
def predict(sent,vocab,p,batch_size=1):
    ''' Function to predict the summary of the source text sentence
        Input:
        - sent: string, text to summarize
        - vocab: a class Vocab object, vocabulary of the texts
        - p: a class Parameters object, model parameters
        - batch_size: integer, batch size of the data to predict
    '''
    eps=p.eps
    DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    # Create a tensor with the embedding vectors
    embedding_weights = torch.from_numpy(vocab.embeddings).to(DEVICE)
    # Create the layer to transform inputs between encoder and decoder
    enc_dec_adapter = nn.Linear(p.hidden_size * 2, p.dec_hidden_size).to(DEVICE)
    # Create the embedding layer using the embedding vectors
    embedding = nn.Embedding(128, p.embed_size, padding_idx=vocab.PAD,_weight=embedding_weights).to(DEVICE)
    # Create the encoder and the decoder
    encoder = EncoderRNN(p.embed_size, p.hidden_size, p.enc_bidi,rnn_drop=p.enc_rnn_dropout).to(DEVICE)
    decoder = DecoderRNN(len(vocab), p.embed_size, p.dec_hidden_size,
                                  enc_attn=p.enc_attn, dec_attn=p.dec_attn,
                                  pointer=p.pointer,
                                  in_drop=p.dec_in_dropout, rnn_drop=p.dec_rnn_dropout,
                                  out_drop=p.dec_out_dropout, enc_hidden_size=p.hidden_size * 2,
                                  device=DEVICE).to(DEVICE) 
    # Tokenize the input text 
    sent_vec=[vocab[word] for word in sent.split()]
    vocab_ext=deepcopy(vocab)
    # Extend the vocabulary
    for word in sent.split():
      vocab_ext.add_words(word)
    # Tokenize the text with the extended  vocabulary
    sent_vec_extra=[vocab_ext[word] for word in sent.split()] 
    # Pad the text if neccessary
    if(len(sent_vec_extra)<p.max_src_len):
        pad_dim = (0, p.max_src_len-len(sent_vec_extra))
        #sent_vec_extra=F.pad(sent_vec_extra, pad_dim , 'constant')
        sent_vec_extra_tensor=F.pad(torch.tensor(sent_vec_extra), pad_dim , 'constant')
    else:
        sent_vec_extra_tensor=torch.tensor(sent_vec_extra)
        
    # Pad the text if neccessary
    if(len(sent_vec)<p.max_src_len):
        pad_dim = (0, p.max_src_len-len(sent_vec))
        #sent_vec=F.pad(sent_vec, pad_dim, 'constant')
        sent_vec_tensor=F.pad(torch.tensor(sent_vec), pad_dim, 'constant')
    else:
        sent_vec_tensor=torch.tensor(sent_vec)
        
    # Load the encoder model from file
    if(os.path.exists(p.encoder_weights_path)):
        encoder.load_state_dict(torch.load(p.encoder_weights_path,map_location=torch.device(DEVICE)))
    # Load the decoder model from file
    if(os.path.exists(p.decoder_weights_path)):
        decoder.load_state_dict(torch.load(p.decoder_weights_path,map_location=torch.device(DEVICE)))
    # Load the encoder -decoder adapter component from file
    if(os.path.exists(p.encoder_decoder_adapter_weights_path)):    
        enc_dec_adapter.load_state_dict(torch.load(p.encoder_decoder_adapter_weights_path,map_location=torch.device(DEVICE)))

    x=sent_vec_tensor.view(1,-1).to(DEVICE)
    x_extra=sent_vec_extra_tensor.view(1,-1).to(DEVICE)
    # Apply the embedding layer
    encoder_embedded = embedding(x)
    # Initiaize the hidden state of the encoder
    encoder_hidden=encoder.init_hidden(x.size(0), DEVICE)
    # Fordward pass to the encoder
    encoder_outputs, encoder_hidden =encoder(encoder_embedded,encoder_hidden,
                                             torch.tensor(p.max_src_len).view(1).to(DEVICE))
    # Initialize the decoder input to SOS tokens
    decoder_input = torch.tensor([vocab.SOS] * batch_size, device=DEVICE)
    decoder_hidden = enc_dec_adapter(encoder_hidden)
    
    #Initialize the hidden states and weights of some variables
    decoder_states = []
    enc_attn_weights = []
    output=[]
    # For every word in the output sequence 
    for di in range(p.max_tgt_len):
        # Apply the embedding layer of the decoder
        decoder_embedded = embedding(decoder_input)
        # Get the coverage vector
        if enc_attn_weights:
            coverage_vector = get_coverage_vector(enc_attn_weights)
        else:
            coverage_vector = None
        # fordward pass to the decoder
        decoder_output, decoder_hidden, dec_enc_attn, dec_prob_ptr = decoder(decoder_embedded, decoder_hidden, encoder_outputs,
                    torch.cat(decoder_states).to(DEVICE) if decoder_states else None, coverage_vector,
                    encoder_word_idx=x_extra,log_prob=True,ext_vocab_size=len(vocab_ext))  
        # Move the tensor to the device
        decoder_output.to(DEVICE)
        decoder_hidden.to(DEVICE)
        dec_enc_attn.to(DEVICE)
        dec_prob_ptr.to(DEVICE)
        # Store the hidden state of the decoder
        decoder_states.append(decoder_hidden)
        # Generate the probability distribution
        prob_distribution = torch.exp(decoder_output)# if log_prob else decoder_output
        # Get the element in the decoder output with the highest probability (the best output)
        _, top_idx = decoder_output.data.topk(1)
        # Store the output (word) to the output text
        output.append(top_idx.squeeze().data.item())
        # Store the encoder attention weights
        enc_attn_weights.append(dec_enc_attn.unsqueeze(0))
        # Set the decoder input in the next iter
        decoder_input = top_idx.view(-1)
    # Transform the outputs (words) to a list of text or words
    output=[vocab_ext[idx] for idx in output]    
    return output

# %%
def prediction(sent,vocab,embedding, encoder, enc_dec_adapter, decoder, device, p,batch_size=1):
    ''' Function to predict the summary of the source text sentence
        Input:
        - sent: string, text to summarize
        - vocab: a class Vocab object, vocabulary of the texts
        - p: a class Parameters object, model parameters
        - batch_size: integer, batch size of the data to predict
    '''
    eps=p.eps
    # Tokenize the input text 
    sent_vec=[vocab[word] for word in sent.split()]
    vocab_ext=deepcopy(vocab)
    # Extend the vocabulary
    for word in sent.split():
      vocab_ext.add_words(word)
    # Tokenize the text with the extended  vocabulary
    sent_vec_extra=[vocab_ext[word] for word in sent.split()] 
    # Pad the text if neccessary
    if(len(sent_vec_extra)<p.max_src_len):
        pad_dim = (0, p.max_src_len-len(sent_vec_extra))
        #sent_vec_extra=F.pad(sent_vec_extra, pad_dim , 'constant')
        sent_vec_extra_tensor=F.pad(torch.tensor(sent_vec_extra), pad_dim , 'constant')
    else:
        sent_vec_extra_tensor=torch.tensor(sent_vec_extra)
        
    # Pad the text if neccessary
    if(len(sent_vec)<p.max_src_len):
        pad_dim = (0, p.max_src_len-len(sent_vec))
        #sent_vec=F.pad(sent_vec, pad_dim, 'constant')
        sent_vec_tensor=F.pad(torch.tensor(sent_vec), pad_dim, 'constant')
    else:
        sent_vec_tensor=torch.tensor(sent_vec)
        
    x=sent_vec_tensor.view(1,-1).to(device)
    x_extra=sent_vec_extra_tensor.view(1,-1).to(device)
    # Apply the embedding layer
    encoder_embedded = embedding(x)
    # Initiaize the hidden state of the encoder
    encoder_hidden=encoder.init_hidden(x.size(0), device)
    # Fordward pass to the encoder
    encoder_outputs, encoder_hidden =encoder(encoder_embedded,encoder_hidden,
                                             torch.tensor(p.max_src_len).view(1).to(device))
    # Initialize the decoder input to SOS tokens
    decoder_input = torch.tensor([vocab.SOS] * batch_size, device=device)
    decoder_hidden = enc_dec_adapter(encoder_hidden)
    
    #Initialize the hidden states and weights of some variables
    decoder_states = []
    enc_attn_weights = []
    output=[]
    # For every word in the output sequence 
    for di in range(p.max_tgt_len):
        # Apply the embedding layer of the decoder
        decoder_embedded = embedding(decoder_input)
        # Get the coverage vector
        if enc_attn_weights:
            coverage_vector = get_coverage_vector(enc_attn_weights)
        else:
            coverage_vector = None
            
        # fordward pass to the decoder
        decoder_output, decoder_hidden, dec_enc_attn, dec_prob_ptr = decoder(decoder_embedded, decoder_hidden, encoder_outputs,
                    torch.cat(decoder_states).to(device) if decoder_states else None, coverage_vector,
                    encoder_word_idx=x_extra,log_prob=True,ext_vocab_size=len(vocab_ext))  
        # Move the tensor to the device
        decoder_output.to(device)
        decoder_hidden.to(device)
        dec_enc_attn.to(device)
        dec_prob_ptr.to(device)
        # Store the hidden state of the decoder
        decoder_states.append(decoder_hidden)
        # Generate the probability distribution
        prob_distribution = torch.exp(decoder_output)# if log_prob else decoder_output
        # Get the element in the decoder output with the highest probability (the best output)
        _, top_idx = decoder_output.data.topk(1)
        # Store the output (word) to the output text
        output.append(top_idx.squeeze().data.item())
        # Store the encoder attention weights
        enc_attn_weights.append(dec_enc_attn.unsqueeze(0))
        # Set the decoder input in the next iter
        decoder_input = top_idx.view(-1)
        
    # Transform the outputs (words) to a list of text or words
    output=[vocab_ext[idx] for idx in output]    
    return output

# %%
def eval_metrics(preds, targets, avg=True):
    ''' Evaluate the ROUGE metrics ROUGE-2 and ROUGE-L for every pair predicted summary - target summary
    
        Input:
           - preds: list of strings, predicted summaries
           - targets: list of string, target summaries
        Output:
            - rouge2_f_metric: list of float, the Rouge-2 fscore for every predicted summary
            - rougel_f_metric: list of float, the Rouge-L fscore for every predicted summary
    '''
    #Lets calculate the rouge metrics for every document
    rouge = Rouge()
    scores = rouge.get_scores(preds, targets, avg)
    # Create the output variables
    if avg:
        rouge2_f_metric = scores['rouge-2']['f']
        rouge2_p_metric = scores['rouge-2']['p']
        rouge2_r_metric = scores['rouge-2']['r']
        rougel_f_metric = scores['rouge-l']['f']
        rougel_p_metric = scores['rouge-l']['p']
        rougel_r_metric = scores['rouge-l']['r']
    else:
        rouge2_f_metric = [score['rouge-2']['f'] for score in scores]
        rouge2_p_metric = [score['rouge-2']['p'] for score in scores]
        rouge2_r_metric = [score['rouge-2']['r'] for score in scores]
        rougel_f_metric = [score['rouge-l']['f'] for score in scores]
        rougel_p_metric = [score['rouge-l']['p'] for score in scores]
        rougel_r_metric = [score['rouge-l']['r'] for score in scores]
    
    return rouge2_f_metric, rouge2_p_metric, rouge2_r_metric, rougel_f_metric, rougel_p_metric, rougel_r_metric

def save_to_df(text, labeled_summaries, predicted_summaries, r2_f, r2_p, r2_r, rl_f, rl_p, rl_r):
    ''' Stores the metric results into a pandas dataframe'''
    results = pd.DataFrame(columns=['text', 'summary','pred_summary','rouge2-f','rouge2-p','rouge2-r','rougel-f', 'rougel-p', 'rougel-r'])
    results['text'] = text
    results['summary'] = labeled_summaries
    results['pred_summary'] = predicted_summaries
    results['rouge2-f'] = r2_f
    results['rouge2-p'] = r2_p
    results['rouge2-r'] = r2_r
    results['rougel-f'] = rl_f
    results['rougel-p'] = rl_p
    results['rougel-r'] = rl_r

    return results

# %%
def get_predictions(x_test, vocab, params, print_every=20):
    ''' Generate the predicted summaries of the source texts on x_test
        Input:
        - x_test: list of strings, the source texts
        - vocab: a Vocab Class object, vocabulary of the texts
        - params: a Parameters object, parameter of the model
        - print_every: integer, print progress every print_every iterations
    '''
    DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    # Create a tensor with the embedding vectors
    embedding_weights = torch.from_numpy(vocab.embeddings).to(DEVICE)
    # Create the layer to transform inputs between encoder and decoder
    enc_dec_adapter = nn.Linear(params.hidden_size * 2, params.dec_hidden_size).to(DEVICE)
    # Create the embedding layer using the embedding vectors
    embedding = nn.Embedding(len(vocab), params.embed_size, padding_idx=vocab.PAD,_weight=embedding_weights).to(DEVICE)
    # Create the encoder and the decoder
    encoder = EncoderRNN(params.embed_size,params.hidden_size, params.enc_bidi,rnn_drop=params.enc_rnn_dropout).to(DEVICE)
    decoder = DecoderRNN(len(vocab), params.embed_size, params.dec_hidden_size,
                                  enc_attn=params.enc_attn, dec_attn=params.dec_attn,
                                  pointer=params.pointer,
                                  in_drop=params.dec_in_dropout, rnn_drop=params.dec_rnn_dropout,
                                  out_drop=params.dec_out_dropout, enc_hidden_size=params.hidden_size * 2,
                                  device=DEVICE).to(DEVICE) 

    # Load the encoder model from file
    if(os.path.exists(params.encoder_weights_path)):
        encoder.load_state_dict(torch.load(params.encoder_weights_path,map_location=torch.device(DEVICE)))
    # Load the decoder model from file
    if(os.path.exists(params.decoder_weights_path)):
        decoder.load_state_dict(torch.load(params.decoder_weights_path,map_location=torch.device(DEVICE)))
    # Load the encoder -decoder adapter component from file
    if(os.path.exists(params.encoder_decoder_adapter_weights_path)):    
        enc_dec_adapter.load_state_dict(torch.load(params.encoder_decoder_adapter_weights_path,map_location=torch.device(DEVICE)))

        
    predicted_summaries = []
    # Set a progress bar
    kbar = pkbar.Kbar(target=len(x_test), width=8)
    # For every text in the validation dataset
    for i,doc in enumerate(x_test):
        # Predict the summary for the document
        pred_summ = prediction(doc,vocab,embedding,encoder,enc_dec_adapter,decoder,DEVICE,params,batch_size=1)
        #pred_summ = predict(doc,vocab,params,batch_size=1)
        predicted_summaries.append(' '.join(pred_summ))
        #Show the progress
        if i%print_every==0:
            kbar.update(i)
            
    # Set the labeled summaries as the y_test variable, column summary of our dataset
    return predicted_summaries

# %%
def generate_predictions(x_test, vocab, params, print_every=20):
    ''' Generate the predicted summaries of the source texts on x_test
        Input:
        - x_test: list of strings, the source texts
        - vocab: a Vocab Class object, vocabulary of the texts
        - params: a Parameters object, parameter of the model
        - print_every: integer, print progress every print_every iterations
    '''

    predicted_summaries = []
    # Set a progress bar
    kbar = pkbar.Kbar(target=len(x_test), width=8)
    # For every text in the validation dataset
    for i,doc in enumerate(x_test):
        # Predict the summary for the document
        pred_summ = predict(doc,vocab,params,batch_size=1)
        predicted_summaries.append(' '.join(pred_summ))
        #Show the progress
        if i%print_every==0:
            kbar.update(i)
            
    # Set the labeled summaries as the y_test variable, column summary of our dataset
    return predicted_summaries

# %%
params =Parameters()

dataset = Dataset(params.data_path, simple_tokenizer, params.max_src_len, params.max_tgt_len, max_rows=64000,
                        truncate_src=True, truncate_tgt=True)
# Load the validation dataset using the simple tokenizer
valid_dataset = Dataset(params.val_data_path, simple_tokenizer, params.max_src_len, params.max_tgt_len, max_rows= 3200,
                        truncate_src=True, truncate_tgt=True)
#Show the length to check the loadings
print(dataset.src_len, valid_dataset.src_len,dataset.tgt_len, valid_dataset.tgt_len)
# Out:
# Reading dataset /workspace/myproject/train_w_splits - train_w_splits.csv... 58527 pairs.
# Reading dataset /workspace/myproject/val_w_splits - val_w_splits.csv... 3200 pairs.
# 22 17 16 16

# %%
# def remove_colons_from_file(input_file, output_file):
#     with open(input_file, 'r', encoding = 'utf-8') as file:
#         text = file.read()  # Read the contents of the file

#     # Remove all colons
#     updated_text = text.replace(':', '')

#     # Write the updated content to the output file
#     with open(output_file, 'w', encoding= 'utf-8') as file:
#         file.write(updated_text)
#     print("Jai SHree Ram")
# p = Parameters()
# # Example usage
# input_file = p.embed_file  # Replace with your file path
# output_file = p.embed_file  # Replace with your output file path
# remove_colons_from_file(input_file, output_file)

# %%
vocab = dataset.build_vocab(params.vocab_min_frequency, embed_file=params.embed_file)
vocab.save_to_file('vocab_train.pkl')
# convert the embeddings to a tensor
embedding_weights = torch.from_numpy(vocab.embeddings)
# Out:
# 93
# 77
# 77 pre-trained embeddings loaded.

# %%
train(dataset,valid_dataset,vocab, params, embedding_weights,learning_rate=0.001,num_epochs = 10)
# Out:
# Epoch: 1/10
# /workspace/myproject/sandhi-split/lib/python3.10/site-packages/torch/nn/modules/rnn.py:88: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.1 and num_layers=1
#   warnings.warn("dropout option adds dropout after all but last "
# 57600/58527 [======>.] - ETA: 2s - loss: 8.0409torch.Size([15, 65])
# 57601/58527 [======>.] - ETA: 2s - loss: 8.0407tensor(0.4868, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.3680, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.4358, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.8316, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.6594, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.9234, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.8913, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.7646, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.0776, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.4803, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.6234, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.1903, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(9.1553, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.1981, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<NllLossBackward0>)
#    0/3200 [........] - ETA: 0s - Val loss: 0.0000e+00tensor(0.0018, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.1418, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.6357, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.4545, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.1107, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.6300, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.8470, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.0110, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.6602, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.9791, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.0058, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.0017, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.3146, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.2770, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.7685, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.0241, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.2891, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.8475, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.9751, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.0863, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.0028, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.0043, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.0219, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.0022, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.5002, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.5739, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.8950, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.7611, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.0799, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.1120, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.3613, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.7483, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(6.9023, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(8.1036, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.9824, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(9.6661, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.0022, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.6802, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.0514, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.5130, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.3506, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.5413, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.0972, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.7045, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.7488, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.9391, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.0188, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.0028, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(9.8174e-05, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.0018, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.0407, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.4378, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.5583, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.2011, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.9999, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.1107, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.8082, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.2847, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.7442, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.9838, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(6.2304, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.2035, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.2583, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.0016, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.0505, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.8628, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.9527, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.2588, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.5812, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.7389, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.3043, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.3143, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.1316, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(7.9374, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.0011, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.0358, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.1343, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.1993, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.7689, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.0408, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.1083, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.0134, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.0014, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.0001, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.0047, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.0394, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.2550, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.3804, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.9180, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.7836, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.5353, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.8214, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.0448, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.4286, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(6.1175, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.0011, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.0313, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.4340, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.0395, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.7711, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.6195, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.1700, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.1358, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.7147, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.1726, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(9.9658, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.8087, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.0027, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.0503, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.7111, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.4845, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.3495, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.3586, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.0062, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.9102, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.0166, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.5474, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.8393, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.8226, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.0014, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.4000, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.6221, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.7133, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.4511, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.0141, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.2149, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.0071, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.0016, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.0042, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.0011, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.0027, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.4723, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.5655, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.7771, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.7224, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.1723, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.8498, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.3706, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.0002, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.0013, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.0115, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.2027, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.8687, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.6648, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.3887, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.9498, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.7384, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.7030, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.2545, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.7680, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(7.8604, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(7.5591, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(13.9599, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(12.0959, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.0016, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.3376, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.9738, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.1840, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.6737, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.0609, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.0705, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.0160, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.0210, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.0021, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.0012, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.0108, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.5072, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.8082, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.8726, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.5627, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.4170, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.8309, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.4063, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.7668, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.9489, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.8274, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(12.8797, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(9.4291, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.7619, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.0020, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.0209, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.4012, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.1469, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.0681, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.5295, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.8577, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.1278, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.8348, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.7268, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.0022, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.2042, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.3442, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.1135, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.9595, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.0150, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.6451, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.2561, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.0091, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.6162, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.7274, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.3596, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.0018, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.6131, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.7010, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.0938, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.8438, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.3919, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.8723, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.6669, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.0057, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.0008, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.0005, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.0018, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.1397, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.3445, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.7895, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.4906, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.3206, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.6590, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.9640, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.8705, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.0380, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.0010, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.0009, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.0225, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.4627, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.4158, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.4553, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.1364, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.9346, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.1148, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.8866, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(6.3919, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(10.2355, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.0022, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.5768, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.5512, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.3101, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.7467, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.4235, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.8586, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.5897, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.6298, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.2511, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.0872, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.2293, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.0015, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.0581, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.9647, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.7696, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.2479, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.8750, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.7823, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.0680, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.0016, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.0038, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.0013, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.0366, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.2591, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.2252, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.3172, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.0472, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.6828, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(6.0959, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.1365, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(7.7742, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(8.5598, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(15.6566, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(12.2730, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(6.8301, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.0011, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.0219, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.6147, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.0772, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.7233, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.6432, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.1999, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.9613, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.6412, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.0012, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.0187, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.3640, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.6222, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.5202, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.5873, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.7302, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.0870, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.3883, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.4023, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.9411, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(8.5842, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.5604, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.0016, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.0240, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.6244, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.0814, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.1931, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.1500, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.4021, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.0528, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.1065, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.7369, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.0354, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.0010, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.0004, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.0060, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.0019, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.0878, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.3706, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.5034, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.7428, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.9775, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.0880, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.8805, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.0248, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.0024, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.0407, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.1613, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.0023, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.0022, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.0025, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.0286, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.0881, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.2711, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.9536, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.8952, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.0597, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.3234, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.5866, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.8162, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.8006, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.5517, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(9.4112, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(6.3270, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.0020, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.0264, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.0985, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.2862, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.0862, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.9989, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.7058, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.0760, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.0095, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.0033, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.0010, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.0021, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.0403, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.1198, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.1851, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.6657, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.9363, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.1594, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.6321, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.1969, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.4530, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.3713, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.0011, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.0019, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.0549, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.3098, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.0961, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.2062, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.2982, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.3140, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.5177, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.0007, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.0002, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.0017, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.0467, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.3086, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.4552, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.0959, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.1374, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.3011, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.4589, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.9504, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.8140, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.7701, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(6.6634, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.9081, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(9.6805, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.0019, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.0435, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.7949, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.3517, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.4052, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.9219, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.9616, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.3124, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.1131, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(6.8725, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.5660, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(7.4802, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.2267, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.1013, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.0067, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.0016, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.0553, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.0755, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.2575, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.9996, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.6055, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.1052, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.8292, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.5940, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.2303, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.8907, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(9.1526, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(9.7892, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.0123, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.0021, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.0377, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.3627, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.7883, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.5846, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.6211, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.8498, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.1593, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.6810, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.0229, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.0019, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.0592, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.6963, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.2205, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.5405, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.5667, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.2664, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.3825, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.1906, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.4198, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(7.2622, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.1450, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.0039, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.0024, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.0803, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.3847, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.0412, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.6460, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.0614, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.5698, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.8251, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.8473, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.4693, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.6316, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.0015, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.0205, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.1305, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.2548, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.5829, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.9104, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.8068, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.8485, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.8759, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.0039, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.0015, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.0540, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.9533, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.9197, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.1804, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.2342, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.1722, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.9276, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.0073, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.0112, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.0025, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.0370, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.4488, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.2417, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.4578, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.0020, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.7022, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.6079, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.7733, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.4890, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.0769, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.1562, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.0018, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.3097, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.1129, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.5717, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.0667, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.9649, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.5515, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.5499, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.9153, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.1532, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(8.0357, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.6208, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.3955, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(10.9771, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(8.4852, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.0018, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.0668, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.5265, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.5524, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.5851, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.2117, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.8227, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.0667, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.1610, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.2052, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.2389, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.0026, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.0321, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.2571, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.7489, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.3855, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.8306, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.3043, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.4162, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.0245, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.5162, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.2513, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.0002, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.0441, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.0459, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.0012, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.0240, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.1319, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.8349, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.0298, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.1347, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.4272, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.2510, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.0974, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(7.9886, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(8.4738, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(6.9976, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.5004, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(13.3751, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(9.5684, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.0015, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.0351, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.2067, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.2439, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.2502, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.0327, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.6833, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.2848, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.1914, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.0060, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.0021, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.0529, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.5908, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.1598, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.7143, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.5540, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.1983, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.8427, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.0266, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.2422, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.0112, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.0027, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.0613, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.1714, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.8609, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.7721, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.9376, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.2255, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.2428, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.7104, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.6714, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(9.6678, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(17.3048, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(7.7442, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.0032, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.5142, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.6287, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.6100, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.0480, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.4680, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.7348, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.4319, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.1516, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.9270, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.9355, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.0025, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.0024, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.0053, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.0026, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.1013, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.9522, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.3125, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.4886, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.2005, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.4215, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.0893, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.4646, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.3038, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.0564, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.0034, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.0073, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.0015, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.6082, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.2494, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.5185, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.9345, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.5488, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.9898, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.3438, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.0130, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.0066, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.0022, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.0416, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.0941, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.2847, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.2626, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.6250, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.7152, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.9547, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.8929, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.0001, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.0013, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.0229, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.2926, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.2187, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.4270, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.1827, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.2863, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.1739, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.3864, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(7.0598, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.5292, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.0014, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.2903, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.5034, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.3192, device='cuda:0', grad_fn=<NllLossBackward0>)
# ...
# tensor(0.3774, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.7684, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.2943, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.9894, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.3389, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.3895, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.3109, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(17.1268, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.0737, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(7.0649, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.2054, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.0018, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.5893, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.5515, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.2747, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.1417, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.2249, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.9292, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.3849, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.1218, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(9.4772e-06, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.0039, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.6577, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.4620, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.2219, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.5405, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.4980, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.0623, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.0084, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.0013, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.0051, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.0005, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.0002, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.0016, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.0018, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.4213, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.1690, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.1178, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.2686, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.5065, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.4679, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.0388, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(7.2199, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.2182, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.0005, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.0012, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.2449, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.1191, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.3536, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.1112, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.1068, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.3841, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.8680, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.5208, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.5176e-05, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(8.4639e-06, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.0006, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.0014, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.2936, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.7141, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.0346, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.3190, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.7165, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.5637, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.0084, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.0152, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.1044, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(6.7566e-05, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.0186, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.1593, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.3057, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.9500, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.9473, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.8661, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.6652, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.0001, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.0037, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.0280, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.0123, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.0005, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.1662, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.1630, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.5500, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.9423, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.8664, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.0063, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.1023, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.6490, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.0021, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(7.4506e-06, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.1723e-07, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.6479e-05, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.0164, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.1827, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.4628, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.1754, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.2111, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.0901, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.8245, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.0828, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.8860, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.0054, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.0001, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.0013, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.1551, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.5354, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.5550, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.7832, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.7635, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.7728, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.0010, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.0592e-05, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(6.9683e-05, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.0037, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.0028, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.1623e-05, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.2999, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.1513, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.8805, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.1455, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.4064, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.7390, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.0018, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.0002, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.0014, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.0032, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.0095, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.2729, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.8555, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.5523, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.4883, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.6309, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.6912, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.0020, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.4770e-06, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.0002, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(8.4269e-06, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.1868, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.7362, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.8132, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.1447, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.7603, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.0027, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.0110, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.0111, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.7343, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(7.1134e-05, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.7432e-05, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.0068, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.4406e-05, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.0514, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.9661, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.5166, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.7950, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.5229, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.3900, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.3259, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.0012, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.3359, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.0386, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.2078, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.0004, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.0444, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.0345, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.1581, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.2921, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.4944, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.5579, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.7757, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.4210, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.4758, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.8477e-06, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.0002, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.0109, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.0100, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.1198, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.2075, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.7076, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.3072, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.0015, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.0001, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.0005, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.0002, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.0038, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.0711, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.3764, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.8591, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.8166, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.5740, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.8881, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.0002, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.6589, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.0118, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.0031, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.0239, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.4190, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.5901, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.7401, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.7447, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.0499, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.0042, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.5830e-06, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<NllLossBackward0>)
# 1601/3200 [===>....] - ETA: 4s - Val loss: 2264.4719 - Train loss: 0.0579 - Avg Val loss: 1.2873

# %%
df = pd.read_csv(r"/workspace/myproject/test_w_splits-test_w_splits.csv")

x_test = df['Word']

y_pred = get_predictions(x_test, vocab, params)

y_pred[:5]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df = pd.read_csv(r"/workspace/myproject/test_w_splits-test_w_splits.csv")
#       3 x_test = df['Word']
#       5 y_pred = get_predictions(x_test, vocab, params)
#
# NameError: name 'pd' is not defined
